# %% [markdown]
# # Another questions from the CEO

# %%
import folium
import pandas as pd
import plotly.express as px

data = pd.read_csv("../AB_NYC_2019.csv")

# %%
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# ### What is the most expensive rent (daily) in each region in the NYC?
#
# Select columns ``price`` and ``neighbourhood_group``
#
# 1. Find the most expensive rent by region
# 2. Plot a bar chart with the most expensive rent by region

# %%
columns = ["price", "neighbourhood_group"]

highest_price_byregion = (
    data.loc[:, columns].groupby("neighbourhood_group").max().reset_index()
)

print(f"The average rental values by region are: \n{highest_price_byregion}")
# Out:
# The average rental values by region are:
#   neighbourhood_group  price
# 0               Bronx   2500
# 1            Brooklyn  10000
# 2           Manhattan  10000
# 3              Queens  10000
# 4       Staten Island   5000

# %%
px.bar(highest_price_byregion, x="neighbourhood_group", y="price")

# %% [markdown]
# ### Can we know where the most expensive rental properties are located in NYC?
#
# Select columns ``price``, ``neighbourhood_group``, ``latitude`` and ``longitude``
#
# 1. Find the most expensive rent by region
# 2. Plot the most expensive rent by region in a map

# %%
columns = ["price", "neighbourhood_group", "latitude", "longitude"]

data_plot = data.loc[:, columns].groupby("neighbourhood_group").max().reset_index()

data_plot
# Out:
#   neighbourhood_group  price  latitude  longitude
# 0               Bronx   2500  40.91306  -73.78158
# 1            Brooklyn  10000  40.73890  -73.85676
# 2           Manhattan  10000  40.87665  -73.90855
# 3              Queens  10000  40.79721  -73.71299
# 4       Staten Island   5000  40.64779  -74.06092

# %%
map = folium.Map()

for index, location_info in data_plot.iterrows():
    folium.Marker(
        [location_info["latitude"], location_info["longitude"]],
        popup=location_info[["neighbourhood_group", "price"]],
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84c2fa7a9d17204e2d07df4a417ad726 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84c2fa7a9d17204e2d07df4a417ad726&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84c2fa7a9d17204e2d07df4a417ad726 = L.map(
#                 &quot;map_84c2fa7a9d17204e2d07df4a417ad726&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30f20a8f59d0e4eb618ffa59cc3d1623 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30f20a8f59d0e4eb618ffa59cc3d1623.addTo(map_84c2fa7a9d17204e2d07df4a417ad726);
#
#
#             var marker_1c47ae763ee7d8e6b5ef435ec345aff3 = L.marker(
#                 [40.91306, -73.78158],
#                 {}
#             ).addTo(map_84c2fa7a9d17204e2d07df4a417ad726);
#
#
#         var popup_fe469b346df3f77a486eda4467ccd478 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94ece7486ef927b238ca9374fb76a826 = $(`&lt;div id=&quot;html_94ece7486ef927b238ca9374fb76a826&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group    Bronx price                   2500 Name: 0, dtype: object&lt;/div&gt;`)[0];
#                 popup_fe469b346df3f77a486eda4467ccd478.setContent(html_94ece7486ef927b238ca9374fb76a826);
#
#
#
#         marker_1c47ae763ee7d8e6b5ef435ec345aff3.bindPopup(popup_fe469b346df3f77a486eda4467ccd478)
#         ;
#
#
#
#
#             var marker_22f45d7cda33fe3a0ea17021c2e3b444 = L.marker(
#                 [40.7389, -73.85676],
#                 {}
#             ).addTo(map_84c2fa7a9d17204e2d07df4a417ad726);
#
#
#         var popup_d6db85cb2d46aa9cc437066a68401c66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e668885f54b6a092abd765a2e956fec = $(`&lt;div id=&quot;html_4e668885f54b6a092abd765a2e956fec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group    Brooklyn price                     10000 Name: 1, dtype: object&lt;/div&gt;`)[0];
#                 popup_d6db85cb2d46aa9cc437066a68401c66.setContent(html_4e668885f54b6a092abd765a2e956fec);
#
#
#
#         marker_22f45d7cda33fe3a0ea17021c2e3b444.bindPopup(popup_d6db85cb2d46aa9cc437066a68401c66)
#         ;
#
#
#
#
#             var marker_1c32db51fdc8cc3c1e683d48fcfb09e4 = L.marker(
#                 [40.87665, -73.90855],
#                 {}
#             ).addTo(map_84c2fa7a9d17204e2d07df4a417ad726);
#
#
#         var popup_83e68e052978f52520a143ef6c20e206 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b6c2a352a6ae40303828b857a9d9495 = $(`&lt;div id=&quot;html_8b6c2a352a6ae40303828b857a9d9495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group    Manhattan price                      10000 Name: 2, dtype: object&lt;/div&gt;`)[0];
#                 popup_83e68e052978f52520a143ef6c20e206.setContent(html_8b6c2a352a6ae40303828b857a9d9495);
#
#
#
#         marker_1c32db51fdc8cc3c1e683d48fcfb09e4.bindPopup(popup_83e68e052978f52520a143ef6c20e206)
#         ;
#
#
#
#
#             var marker_5456c4e4e812e240163c837bcfc0aeaa = L.marker(
#                 [40.79721, -73.71299],
#                 {}
#             ).addTo(map_84c2fa7a9d17204e2d07df4a417ad726);
#
#
#         var popup_81850107ff4ace3faa9147346dc14edb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b438b57e38b5f5155ed5cfd3bbbe359 = $(`&lt;div id=&quot;html_3b438b57e38b5f5155ed5cfd3bbbe359&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group    Queens price                   10000 Name: 3, dtype: object&lt;/div&gt;`)[0];
#                 popup_81850107ff4ace3faa9147346dc14edb.setContent(html_3b438b57e38b5f5155ed5cfd3bbbe359);
#
#
#
#         marker_5456c4e4e812e240163c837bcfc0aeaa.bindPopup(popup_81850107ff4ace3faa9147346dc14edb)
#         ;
#
#
#
#
#             var marker_463bf09d3551a6905eeb5e8801338684 = L.marker(
#                 [40.64779, -74.06092],
#                 {}
#             ).addTo(map_84c2fa7a9d17204e2d07df4a417ad726);
#
#
#         var popup_e7b59b57c3c2d1a31da5971ea2ae2f5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d595f97fdfdfc9913c1a2609411eeed3 = $(`&lt;div id=&quot;html_d595f97fdfdfc9913c1a2609411eeed3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group    Staten Island price                           5000 Name: 4, dtype: object&lt;/div&gt;`)[0];
#                 popup_e7b59b57c3c2d1a31da5971ea2ae2f5c.setContent(html_d595f97fdfdfc9913c1a2609411eee

# %% [markdown]
# ### Can we know where properties are located by their type?
#
# Select columns ``room_type``, ``neighbourhood_group``,``latitude`` and ``longitude``
#
# 1. Generate a sample with 100 rows randomly select
# 2. Plot the sample in a map with different colors by ``room_type``

# %%
columns = ["room_type", "neighbourhood_group", "latitude", "longitude"]

data_plot = data.loc[:, columns].sample(100)

data_plot
# Out:
#              room_type neighbourhood_group  latitude  longitude
# 17511  Entire home/apt           Manhattan  40.77770  -73.95350
# 12134  Entire home/apt           Manhattan  40.87045  -73.91830
# 3235      Private room           Manhattan  40.72373  -73.99118
# 45615     Private room           Manhattan  40.82509  -73.95220
# 19891  Entire home/apt              Queens  40.77145  -73.93008
# ...                ...                 ...       ...        ...
# 42821     Private room            Brooklyn  40.67876  -73.91096
# 34426  Entire home/apt           Manhattan  40.77320  -73.95029
# 28253  Entire home/apt            Brooklyn  40.68165  -73.96006
# 2666      Private room           Manhattan  40.74036  -74.00138
# 7139      Private room           Manhattan  40.82153  -73.94651
#
# [100 rows x 4 columns]

# %%
# Create a new column called 'color' and filling with NA
data_plot.loc[:, "color"] = "NA"

# Select lines by type of room
lines_private_room = data_plot.loc[:, "room_type"] == "Private room"
lines_entire_apt = data_plot.loc[:, "room_type"] == "Entire home/apt"
lines_shared_room = data_plot.loc[:, "room_type"] == "Shared room"

# Define colors to each type of room
data_plot.loc[lines_private_room, "color"] = "darkgreen"
data_plot.loc[lines_entire_apt, "color"] = "darkred"
data_plot.loc[lines_shared_room, "color"] = "purple"

# %%
map = folium.Map()

for index, location_info in data_plot.iterrows():
    folium.Marker(
        [location_info["latitude"], location_info["longitude"]],
        popup=location_info[["neighbourhood_group", "room_type"]],
        icon=folium.Icon(color=location_info["color"]),
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac5fbc980bc0884a068c2363a3fe5576 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac5fbc980bc0884a068c2363a3fe5576&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac5fbc980bc0884a068c2363a3fe5576 = L.map(
#                 &quot;map_ac5fbc980bc0884a068c2363a3fe5576&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6caaab702100f57c23b47055157e6a59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6caaab702100f57c23b47055157e6a59.addTo(map_ac5fbc980bc0884a068c2363a3fe5576);
#
#
#             var marker_9ae202b36450f31a87a5836f44491441 = L.marker(
#                 [40.7777, -73.9535],
#                 {}
#             ).addTo(map_ac5fbc980bc0884a068c2363a3fe5576);
#
#
#             var icon_3a057da863fd67ae44b3bcce472ade41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9ae202b36450f31a87a5836f44491441.setIcon(icon_3a057da863fd67ae44b3bcce472ade41);
#
#
#         var popup_78b14e94d3bbc438da00dd9d4903ff29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6eb5f27c0173257fbf84219d881d56b6 = $(`&lt;div id=&quot;html_6eb5f27c0173257fbf84219d881d56b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group          Manhattan room_type              Entire home/apt Name: 17511, dtype: object&lt;/div&gt;`)[0];
#                 popup_78b14e94d3bbc438da00dd9d4903ff29.setContent(html_6eb5f27c0173257fbf84219d881d56b6);
#
#
#
#         marker_9ae202b36450f31a87a5836f44491441.bindPopup(popup_78b14e94d3bbc438da00dd9d4903ff29)
#         ;
#
#
#
#
#             var marker_7b751041ceeca67c2a828c24b3046999 = L.marker(
#                 [40.87045, -73.9183],
#                 {}
#             ).addTo(map_ac5fbc980bc0884a068c2363a3fe5576);
#
#
#             var icon_daf45d8c754dec9cf3b890376b91f2f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7b751041ceeca67c2a828c24b3046999.setIcon(icon_daf45d8c754dec9cf3b890376b91f2f5);
#
#
#         var popup_e29ba4517a6c66191fbb48cf51935693 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_69501ab1f9f20c8a432cde7c9cfc7089 = $(`&lt;div id=&quot;html_69501ab1f9f20c8a432cde7c9cfc7089&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group          Manhattan room_type              Entire home/apt Name: 12134, dtype: object&lt;/div&gt;`)[0];
#                 popup_e29ba4517a6c66191fbb48cf51935693.setContent(html_69501ab1f9f20c8a432cde7c9cfc7089);
#
#
#
#         marker_7b751041ceeca67c2a828c24b3046999.bindPopup(popup_e29ba4517a6c66191fbb48cf51935693)
#         ;
#
#
#
#
#             var marker_dbd9b2cbb27f3e1ced5e0adda9426833 = L.marker(
#                 [40.72373, -73.99118],
#                 {}
#             ).addTo(map_ac5fbc980bc0884a068c2363a3fe5576);
#
#
#             var icon_586e07e2303918637a6b73ebbf924e96 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dbd9b2cbb27f3e1ced5e0adda9426833.setIcon(icon_586e07e2303918637a6b73ebbf924e96);
#
#
#         var popup_0020be4cae954c36f87a73867cbac430 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9f392b070dc0e64fabad92f68d38e9c = $(`&lt;div id=&quot;html_b9f392b070dc0e64fabad92f68d38e9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group       Manhattan room_type              Private room Name: 3235, dtype: object&lt;/div&gt;`)[0];
#                 popup_0020be4cae954c36f87a73867cbac430.setContent(html_b9f392b070dc0e64fabad92f68d38e9c);
#
#
#
#         marker_dbd9b2cbb27f3e1ced5e0adda9426833.bindPopup(popup_0020be4cae954c36f87a73867cbac430)
#         ;
#
#
#
#
#             var marker_47d1be968b47cb7c7f57f1c6822db2d1 = L.marker(
#                 [40.82509, -73.9522],
#                 {}
#             ).addTo(map_ac5fbc980bc0884a068c2363a3fe5576);
